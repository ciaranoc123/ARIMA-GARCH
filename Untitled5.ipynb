# %%
import pandas as pd

from pandas import concat


import statsmodels.api as sm

from sklearn import metrics
from sklearn import preprocessing as prep
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

import statsmodels as sms
import statsmodels.tsa as tsa
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pmdarima as pm
import pandas_datareader as web
from arch import  arch_model

# %%
stock = web.get_data_yahoo("GOOGL",
start = "2021-01-01",
end = "2021-11-17")
y=stock['Adj Close']

Y_t=y.T
Y_t=Y_t.iloc[1:167]
Y_train=Y_t

model = pm.auto_arima(Y_train, start_p=3, start_q=3,start_d=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=6, max_q=6, max_d=2, # maximum p and q
                      m=1,              # frequency of series
                      d=1,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      #start_P=0, 
                      #D=1, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())

Errors=[]
for i in range(0,13):
    Y_train=Y_t.iloc[:153+i]
    Y_test=Y_t.iloc[153+i:154+i]
    
    arima_model = ARIMA(Y_train, order=model.order)
    arima_model_fit = arima_model.fit()
    preds_arima, se, conf = arima_model_fit.forecast(len(Y_test),alpha=0.3)  
    preds = pd.Series(preds_arima, index=Y_test.index)
    
    mse = mean_squared_error(Y_test, preds)
    rmse = sqrt(mean_squared_error(Y_test, preds))
    mae = mean_absolute_error(Y_test, preds)
    mape=MAPE(Y_test, preds)
    Error_i = ([mse, rmse, mae, mape])
    Errors.append(Error_i)
    Errors_A=pd.DataFrame(Errors)


Errors_1=[]
for i in range(0,13):
    Y_train=Y_t.iloc[:153+i]
    Y_test=Y_t.iloc[153+i:154+i]
    
    arima_model = ARIMA(Y_train, order=model.order)
    arima_model_fit = arima_model.fit()
    preds_arima, se, conf = arima_model_fit.forecast(len(Y_test),alpha=0.3)  
    predicted_arima = pd.Series(preds_arima, index=Y_test.index)

    garch_model = arch_model(Y_train, vol='garch', p=1, q=1)
    garch_model_fit = garch_model.fit()
    preds_garch = garch_model_fit.forecast(horizon=len(Y_test)) 
    predicted_garch = preds_garch.mean['h.1'].iloc[-1]



    # arima_model_fitted = pm.auto_arima(Y_train)
    arima_residuals = arima_model_fit.resid
    p, d, q = model.order
    garch = arch_model(arima_residuals, p=3, q=3)
    garch_fitted = garch.fit()

    predicted_mu = arima_model_fit.forecast(len(Y_test))[0]
    # Use GARCH to predict the residual
    garch_forecast = garch_fitted.forecast(horizon=1)
    garch_pred_mean = garch_forecast.mean['h.1'].iloc[-1]
    garch_pred_var = garch_forecast.variance['h.1'].iloc[-1]


    # Combine both models' output: yt = mu + et
    preds = predicted_mu + garch_pred_mean
    
    mse = mean_squared_error(Y_test, preds)
    rmse = sqrt(mean_squared_error(Y_test, preds))
    mae = mean_absolute_error(Y_test, preds)
    mape=MAPE(Y_test, preds)
    Error_i = ([mse, rmse, mae, mape])
    Errors_1.append(Error_i)
    Errors_GA=pd.DataFrame(Errors_1)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1628.878, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1629.941, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1629.898, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1634.008, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1629.401, Time=0.07 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.544 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  166
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -812.439
# Date:                Mon, 22 Nov 2021   AIC                           1628.878
# Time:                        05:09:45   BIC                           1635.090
# Sample:                             0   HQIC                          1631.400
#                                 - 166
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      6.9933      2.628      2.661      0.008       1.843      12.144
# sigma2      1107.5087     89.448     12.382      0.000     932.194    1282.823
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.95   Jarque-Bera (JB):                25.83
# Prob(Q):                              0.33   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.45   Skew:                             0.33
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 4518.419577732787
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 1004.1927329895552
# Iteration:      3,   Func. Count:     17,   Neg. LLF: 1003.9783681488318
# Iteration:      4,   Func. Count:     22,   Neg. LLF: 1003.3891675955798
# Iteration:      5,   Func. Count:     27,   Neg. LLF: 1003.234173063008
# Iteration:      6,   Func. Count:     32,   Neg. LLF: 1002.5093288376495
# Iteration:      7,   Func. Count:     37,   Neg. LLF: 1000.0173754265865
# Iteration:      8,   Func. Count:     42,   Neg. LLF: 998.279529857125
# Iteration:      9,   Func. Count:     47,   Neg. LLF: 997.9428402446852
# Iteration:     10,   Func. Count:     52,   Neg. LLF: 997.9231712612466
# Iteration:     11,   Func. Count:     57,   Neg. LLF: 997.9228448608085
# Iteration:     12,   Func. Count:     62,   Neg. LLF: 997.9228390482946
# Iteration:     13,   Func. Count:     67,   Neg. LLF: 997.9228335679417
# Iteration:     14,   Func. Count:     72,   Neg. LLF: 997.9228120564085
# Iteration:     15,   Func. Count:     77,   Neg. LLF: 997.9227534982974
# Iteration:     16,   Func. Count:     82,   Neg. LLF: 997.9226219130804
# Iteration:     17,   Func. Count:     87,   Neg. LLF: 997.9222296884453
# Iteration:     18,   Func. Count:     92,   Neg. LLF: 997.9211864777899
# Iteration:     19,   Func. Count:     97,   Neg. LLF: 997.9187044690088
# Iteration:     20,   Func. Count:    102,   Neg. LLF: 997.9116200211895
# Iteration:     21,   Func. Count:    107,   Neg. LLF: 997.8959212469312
# Iteration:     22,   Func. Count:    112,   Neg. LLF: 997.85451742488
# Iteration:     23,   Func. Count:    117,   Neg. LLF: 997.7323447475945
# Iteration:     24,   Func. Count:    122,   Neg. LLF: 997.3922434716392
# Iteration:     25,   Func. Count:    127,   Neg. LLF: 997.3541367782864
# Iteration:     26,   Func. Count:    132,   Neg. LLF: 997.3444911442916
# Iteration:     27,   Func. Count:    137,   Neg. LLF: 997.3439724499161
# Iteration:     28,   Func. Count:    142,   Neg. LLF: 997.3439681538329
# Iteration:     29,   Func. Count:    147,   Neg. LLF: 997.3439667753639
# Iteration:     30,   Func. Count:    152,   Neg. LLF: 997.3440693960264
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 997.3439667757053
#             Iterations: 30
#             Function evaluations: 162
#             Gradient evaluations: 30
# Iteration:      1,   Func. Count:     10,   Neg. LLF: 1260.4787899239136
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 873.0687340988624
# Iteration:      3,   Func. Count:     32,   Neg. LLF: 748.7354723437107
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.875e+04. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.1 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 748.9969239521074
# Iteration:      5,   Func. Count:     51,   Neg. LLF: 748.3771673682271
# Iteration:      6,   Func. Count:     60,   Neg. LLF: 748.3642865695119
# Iteration:      7,   Func. Count:     69,   Neg. LLF: 748.3416141976525
# Iteration:      8,   Func. Count:     78,   Neg. LLF: 748.3397839192196
# Iteration:      9,   Func. Count:     87,   Neg. LLF: 748.3396613399091
# Iteration:     10,   Func. Count:     96,   Neg. LLF: 748.3396195563523
# Iteration:     11,   Func. Count:    105,   Neg. LLF: 748.339389715486
# Iteration:     12,   Func. Count:    114,   Neg. LLF: 748.3386068557647
# Iteration:     13,   Func. Count:    123,   Neg. LLF: 748.3381241726898
# Iteration:     14,   Func. Count:    132,   Neg. LLF: 748.3369210319602
# Iteration:     15,   Func. Count:    141,   Neg. LLF: 748.3349172221688
# Iteration:     16,   Func. Count:    150,   Neg. LLF: 748.3304802607311
# Iteration:     17,   Func. Count:    159,   Neg. LLF: 748.3203935504022
# Iteration:     18,   Func. Count:    168,   Neg. LLF: 748.2955204333265
# Iteration:     19,   Func. Count:    177,   Neg. LLF: 748.2320807043002
# Iteration:     20,   Func. Count:    186,   Neg. LLF: 748.3068012502215
# Iteration:     21,   Func. Count:    196,   Neg. LLF: 748.5211497371413
# Iteration:     22,   Func. Count:    206,   Neg. LLF: 747.7116801411139
# Iteration:     23,   Func. Count:    215,   Neg. LLF: 747.4892335037177
# Iteration:     24,   Func. Count:    224,   Neg. LLF: 748.1008829698096
# Iteration:     25,   Func. Count:    234,   Neg. LLF: 747.4250444451977
# Iteration:     26,   Func. Count:    243,   Neg. LLF: 747.4242652438666
# Iteration:     27,   Func. Count:    252,   Neg. LLF: 747.4241616587647
# Iteration:     28,   Func. Count:    261,   Neg. LLF: 747.4238847506791
# Iteration:     29,   Func. Count:    270,   Neg. LLF: 747.423444573869
# Iteration:     30,   Func. Count:    279,   Neg. LLF: 747.4206401173973
# Iteration:     31,   Func. Count:    288,   Neg. LLF: 747.3497681617307
# Iteration:     32,   Func. Count:    297,   Neg. LLF: 76427090.20363444
# Iteration:     33,   Func. Count:    310,   Neg. LLF: 747.3435506996104
# Iteration:     34,   Func. Count:    319,   Neg. LLF: 747.3420919664051
# Iteration:     35,   Func. Count:    328,   Neg. LLF: 747.3419937275431
# Iteration:     36,   Func. Count:    336,   Neg. LLF: 747.3419937273745
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 747.3419937275431
#             Iterations: 37
#             Function evaluations: 336
#             Gradient evaluations: 36
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 4549.275899461063
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 1010.9276443485687
# Iteration:      3,   Func. Count:     17,   Neg. LLF: 1010.7356688962298
# Iteration:      4,   Func. Count:     22,   Neg. LLF: 1010.2156206904174
# Iteration:      5,   Func. Count:     27,   Neg. LLF: 1010.0888821756992
# Iteration:      6,   Func. Count:     32,   Neg. LLF: 1009.497184720168
# Iteration:      7,   Func. Count:     37,   Neg. LLF: 1007.4401863632384
# Iteration:      8,   Func. Count:     42,   Neg. LLF: 1005.8037455302081
# Iteration:      9,   Func. Count:     47,   Neg. LLF: 1005.5096740132126
# Iteration:     10,   Func. Count:     52,   Neg. LLF: 1005.4980213661271
# Iteration:     11,   Func. Count:     57,   Neg. LLF: 1005.4978745654771
# Iteration:     12,   Func. Count:     62,   Neg. LLF: 1005.4978703872484
# Iteration:     13,   Func. Count:     67,   Neg. LLF: 1005.4978585267843
# Iteration:     14,   Func. Count:     72,   Neg. LLF: 1005.4978251808177
# Iteration:     15,   Func. Count:     77,   Neg. LLF: 1005.4977598619013
# Iteration:     16,   Func. Count:     82,   Neg. LLF: 1005.4974637623122
# Iteration:     17,   Func. Count:     87,   Neg. LLF: 1005.4969562385947
# Iteration:     18,   Func. Count:     92,   Neg. LLF: 1005.4948085337994
# Iteration:     19,   Func. Count:     97,   Neg. LLF: 1005.4900017474038
# Iteration:     20,   Func. Count:    102,   Neg. LLF: 1005.4779800538565
# Iteration:     21,   Func. Count:    107,   Neg. LLF: 1005.4456966770113
# Iteration:     22,   Func. Count:    112,   Neg. LLF: 1005.3899228300916
# Iteration:     23,   Func. Count:    117,   Neg. LLF: 1005.1527088627074
# Iteration:     24,   Func. Count:    122,   Neg. LLF: 1004.929055661982
# Iteration:     25,   Func. Count:    127,   Neg. LLF: 1004.8740234819206
# Iteration:     26,   Func. Count:    132,   Neg. LLF: 1004.8587093632998
# Iteration:     27,   Func. Count:    137,   Neg. LLF: 1004.8563860378147
# Iteration:     28,   Func. Count:    142,   Neg. LLF: 1004.8563224752409
# Iteration:     29,   Func. Count:    146,   Neg. LLF: 1004.856322539128
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1004.8563224752409
#             Iterations: 29
#             Function evaluations: 146
#             Gradient evaluations: 29
# Iteration:      1,   Func. Count:     10,   Neg. LLF: 1268.1366913606778
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 876.5452727460549
# Iteration:      3,   Func. Count:     32,   Neg. LLF: 753.1201004130421
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 753.3877804749745
# Iteration:      5,   Func. Count:     51,   Neg. LLF: 752.6836716427978
# Iteration:      6,   Func. Count:     60,   Neg. LLF: 752.6252241339541
# Iteration:      7,   Func. Count:     69,   Neg. LLF: 752.6205380044023
# Iteration:      8,   Func. Count:     78,   Neg. LLF: 752.6202007076051
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.995e+04. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.1 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      9,   Func. Count:     87,   Neg. LLF: 752.6201403100027
# Iteration:     10,   Func. Count:     96,   Neg. LLF: 752.6199507082613
# Iteration:     11,   Func. Count:    105,   Neg. LLF: 752.6197432100745
# Iteration:     12,   Func. Count:    114,   Neg. LLF: 752.619455111362
# Iteration:     13,   Func. Count:    123,   Neg. LLF: 752.6191355867991
# Iteration:     14,   Func. Count:    132,   Neg. LLF: 752.6185264216981
# Iteration:     15,   Func. Count:    141,   Neg. LLF: 752.6171680588941
# Iteration:     16,   Func. Count:    150,   Neg. LLF: 752.6136771961213
# Iteration:     17,   Func. Count:    159,   Neg. LLF: 752.6046443512346
# Iteration:     18,   Func. Count:    168,   Neg. LLF: 752.57890060856
# Iteration:     19,   Func. Count:    177,   Neg. LLF: 752.5010494376921
# Iteration:     20,   Func. Count:    186,   Neg. LLF: 753.2271413555786
# Iteration:     21,   Func. Count:    196,   Neg. LLF: 752.5610915936701
# Iteration:     22,   Func. Count:    206,   Neg. LLF: 783.6729901331219
# Iteration:     23,   Func. Count:    218,   Neg. LLF: 751.6503830319289
# Iteration:     24,   Func. Count:    227,   Neg. LLF: 751.7653182332982
# Iteration:     25,   Func. Count:    237,   Neg. LLF: 751.6321520220996
# Iteration:     26,   Func. Count:    247,   Neg. LLF: 751.6518182345201
# Iteration:     27,   Func. Count:    257,   Neg. LLF: 751.6149188406931
# Iteration:     28,   Func. Count:    266,   Neg. LLF: 751.6148855113693
# Iteration:     29,   Func. Count:    275,   Neg. LLF: 751.6148507689811
# Iteration:     30,   Func. Count:    284,   Neg. LLF: 751.6146437656212
# Iteration:     31,   Func. Count:    293,   Neg. LLF: 751.61429123821
# Iteration:     32,   Func. Count:    302,   Neg. LLF: 751.6136802685867
# Iteration:     33,   Func. Count:    311,   Neg. LLF: 751.6126967922756
# Iteration:     34,   Func. Count:    320,   Neg. LLF: 751.6104906801552
# Iteration:     35,   Func. Count:    329,   Neg. LLF: 751.6103541050904
# Iteration:     36,   Func. Count:    338,   Neg. LLF: 751.6103470033474
# Iteration:     37,   Func. Count:    347,   Neg. LLF: 751.6103433919473
# Iteration:     38,   Func. Count:    356,   Neg. LLF: 751.6103413438314
# Iteration:     39,   Func. Count:    365,   Neg. LLF: 751.6103292795488
# Iteration:     40,   Func. Count:    374,   Neg. LLF: 751.6102683694203
# Iteration:     41,   Func. Count:    383,   Neg. LLF: 751.6099670092757
# Iteration:     42,   Func. Count:    392,   Neg. LLF: 751.6082804843315
# Iteration:     43,   Func. Count:    401,   Neg. LLF: 751.5960097587817
# Iteration:     44,   Func. Count:    410,   Neg. LLF: 76434232.592866
# Iteration:     45,   Func. Count:    424,   Neg. LLF: 751.5960043954826
# Optimization terminated successfully    (Exit mode 0)
#             Current function value:
Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.1 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 8.372e+04. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.1 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      8,   Func. Count:     75,   Neg. LLF: 799.4791514379009
# Iteration:      9,   Func. Count:     84,   Neg. LLF: 799.464496994424
# Iteration:     10,   Func. Count:     93,   Neg. LLF: 799.4366973456265
# Iteration:     11,   Func. Count:    102,   Neg. LLF: 799.4284012786679
# Iteration:     12,   Func. Count:    111,   Neg. LLF: 799.3929130287714
# Iteration:     13,   Func. Count:    120,   Neg. LLF: 799.3809076788591
# Iteration:     14,   Func. Count:    129,   Neg. LLF: 799.3802764632748
# Iteration:     15,   Func. Count:    138,   Neg. LLF: 799.3802557195208
# Iteration:     16,   Func. Count:    146,   Neg. LLF: 799.3802557191561
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 799.3802557195208
#             Iterations: 16
#             Function evaluations: 146
#             Gradient evaluations: 16
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 4889.056247679577
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 1090.2345929015328
# Iteration:      3,   Func. Count:     17,   Neg. LLF: 1090.2189610872483
# Iteration:      4,   Func. Count:     22,   Neg. LLF: 1090.18488577642
# Iteration:      5,   Func. Count:     27,   Neg. LLF: 1090.1789842248895
# Iteration:      6,   Func. Count:     32,   Neg. LLF: 1090.146435501791
# Iteration:      7,   Func. Count:     37,   Neg. LLF: 1090.0919330687282
# Iteration:      8,   Func. Count:     42,   Neg. LLF: 1089.982885829765
# Iteration:      9,   Func. Count:     47,   Neg. LLF: 1089.818886897278
# Iteration:     10,   Func. Count:     52,   Neg. LLF: 1089.7823201468918
# Iteration:     11,   Func. Count:     57,   Neg. LLF: 1089.7752464437317
# Iteration:     12,   Func. Count:     62,   Neg. LLF: 1089.7750656014678
# Iteration:     13,   Func. Count:     67,   Neg. LLF: 1089.7750532039468
# Iteration:     14,   Func. Count:     72,   Neg. LLF: 1089.7750459720114
# Iteration:     15,   Func. Count:     77,   Neg. LLF: 1089.7749910232274
# Iteration:     16,   Func. Count:     82,   Neg. LLF: 1089.7747293066823
# Iteration:     17,   Func. Count:     87,   Neg. LLF: 1089.7737255997433
# Iteration:     18,   Func. Count:     92,   Neg. LLF: 1089.771928007934
# Iteration:     19,   Func. Count:     97,   Neg. LLF: 1089.7672300603272
# Iteration:     20,   Func. Count:    102,   Neg. LLF: 1089.7546894858292
# Iteration:     21,   Func. Count:    107,   Neg. LLF: 1089.725461698024
# Iteration:     22,   Func. Count:    112,   Neg. LLF: 1089.6365811886758
# Iteration:     23,   Func. Count:    117,   Neg. LLF: 1089.441507625775
# Iteration:     24,   Func. Count:    122,   Neg. LLF: 1089.1976705958468
# Iteration:     25,   Func. Count:    127,   Neg. LLF: 1088.7860134072662
# Iteration:     26,   Func. Count:    132,   Neg. LLF: 1089.06289591036
# Iteration:     27,   Func. Count:    138,   Neg. LLF: 1088.3657394435181
# Iteration:     28,   Func. Count:    143,   Neg. LLF: 1088.3583618393905
# Iteration:     29,   Func. Count:    148,   Neg. LLF: 1088.3583212916215
# Iteration:     30,   Func. Count:    152,   Neg. LLF: 1088.3583213406905
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1088.3583212916215
#             Iterations: 30
#             Function evaluations: 152
#             Gradient evaluations: 30
# Iteration:      1,   Func. Count:     10,   Neg. LLF: 4524.6033856573895
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 804.5447973473748
# Iteration:      3,   Func. Count:     30,   Neg. LLF: 804.0259688799833
# Iteration:      4,   Func. Count:     39,   Neg. LLF: 803.725395198087
# Iteration:      5,   Func. Count:     48,   Neg. LLF: 803.7151108335122
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 803.714890978434
# Iteration:      7,   Func. Count:     66,   Neg. LLF: 803.7137937476197
# Iteration:      8,   Func. Count:     75,   Neg. LLF: 803.7084565819189
# Iteration:      9,   Func. Count:     84,   Neg. LLF: 803.6847803912813
# Iteration:     10,   Func. Count:     93,   Neg. LLF: 803.6218344989934
# Iteration:     11,   Func. Count:    102,   Neg. LLF: 803.6070867441598
# Iteration:     12,   Func. Count:    111,   Neg. LLF: 803.585660205868
# Iteration:     13,   Func. Count:    120,   Neg. LLF: 803.56668478919
# Iteration:     14,   Func. Count:    129,   Neg. LLF: 803.5616231655465
# Iteration:     15,   Func. Count:    138,   Neg. LLF: 803.561303229953
# Iteration:     16,   Func. Count:    147,   Neg. LLF: 803.5612911966543
# Iteration:     17,   Func. Count:    156,   Neg. LLF: 803.5612725620581
# Iteration:     18,   Func. Count:    164,   Neg. LLF: 803.5612725618423
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 803.5612725620581
#             Iterations: 18
#             Function evaluations: 164
#             Gradient evaluations: 18
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
print(Errors_A[3].mean())
print(Errors_GA[3].mean())
# Out:
# 0.7069374403130296
# 0.7069167944026244

# %%
stock = web.get_data_yahoo("BABA",
start = "2021-01-01",
end = "2021-11-17")
y=stock['Adj Close']

Y_t=y.T
Y_t=Y_t.iloc[1:167]
Y_train=Y_t

model = pm.auto_arima(Y_train, start_p=3, start_q=3,start_d=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=6, max_q=6, max_d=2, # maximum p and q
                      m=1,              # frequency of series
                      d=1,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      #start_P=0, 
                      #D=1, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())

Errors=[]
for i in range(0,13):
    Y_train=Y_t.iloc[:153+i]
    Y_test=Y_t.iloc[153+i:154+i]
    
    arima_model = ARIMA(Y_train, order=model.order)
    arima_model_fit = arima_model.fit()
    preds_arima, se, conf = arima_model_fit.forecast(len(Y_test),alpha=0.3)  
    preds = pd.Series(preds_arima, index=Y_test.index)
    
    mse = mean_squared_error(Y_test, preds)
    rmse = sqrt(mean_squared_error(Y_test, preds))
    mae = mean_absolute_error(Y_test, preds)
    mape=MAPE(Y_test, preds)
    Error_i = ([mse, rmse, mae, mape])
    Errors.append(Error_i)
    Errors_A=pd.DataFrame(Errors)


Errors_1=[]
for i in range(0,13):
    Y_train=Y_t.iloc[:153+i]
    Y_test=Y_t.iloc[153+i:154+i]
    
    arima_model = ARIMA(Y_train, order=model.order)
    arima_model_fit = arima_model.fit()
    preds_arima, se, conf = arima_model_fit.forecast(len(Y_test),alpha=0.3)  
    predicted_arima = pd.Series(preds_arima, index=Y_test.index)

    garch_model = arch_model(Y_train, vol='garch', p=1, q=1)
    garch_model_fit = garch_model.fit()
    preds_garch = garch_model_fit.forecast(horizon=len(Y_test)) 
    predicted_garch = preds_garch.mean['h.1'].iloc[-1]



    # arima_model_fitted = pm.auto_arima(Y_train)
    arima_residuals = arima_model_fit.resid
    p, d, q = model.order
    garch = arch_model(arima_residuals, p=3, q=3)
    garch_fitted = garch.fit()

    predicted_mu = arima_model_fit.forecast(len(Y_test))[0]
    # Use GARCH to predict the residual
    garch_forecast = garch_fitted.forecast(horizon=1)
    garch_pred_mean = garch_forecast.mean['h.1'].iloc[-1]
    garch_pred_var = garch_forecast.variance['h.1'].iloc[-1]


    # Combine both models' output: yt = mu + et
    preds = predicted_mu + garch_pred_mean
    
    mse = mean_squared_error(Y_test, preds)
    rmse = sqrt(mean_squared_error(Y_test, preds))
    mae = mean_absolute_error(Y_test, preds)
    mape=MAPE(Y_test, preds)
    Error_i = ([mse, rmse, mae, mape])
    Errors_1.append(Error_i)
    Errors_GA=pd.DataFrame(Errors_1)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 631.379566242789
# Iteration:     12,   Func. Count:     64,   Neg. LLF: 631.3795662819415
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 631.379566242789
#             Iterations: 12
#             Function evaluations: 64
#             Gradient evaluations: 12
# Iteration:      1,   Func. Count:     10,   Neg. LLF: 79224215.22477996
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 483.86420922591344
# Iteration:      3,   Func. Count:     31,   Neg. LLF: 475.617569312349
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 474.97859734875476
# Iteration:      5,   Func. Count:     51,   Neg. LLF: 472.3352866568845
# Iteration:      6,   Func. Count:     60,   Neg. LLF: 472.2383416064069
# Iteration:      7,   Func. Count:     69,   Neg. LLF: 476.50688939863664
# Iteration:      8,   Func. Count:     80,   Neg. LLF: 471.91002830529305
# Iteration:      9,   Func. Count:     89,   Neg. LLF: 471.59488826721224
# Iteration:     10,   Func. Count:     98,   Neg. LLF: 471.2529846114094
# Iteration:     11,   Func. Count:    107,   Neg. LLF: 470.11840840662205
# Iteration:     12,   Func. Count:    116,   Neg. LLF: 469.7253845571922
# Iteration:     13,   Func. Count:    125,   Neg. LLF: 469.68686119820046
# Iteration:     14,   Func. Count:    134,   Neg. LLF: 469.6568592741812
# Iteration:     15,   Func. Count:    143,   Neg. LLF: 469.65502129463744
# Iteration:     16,   Func. Count:    152,   Neg. LLF: 469.65479510055013
# Iteration:     17,   Func. Count:    161,   Neg. LLF: 469.65454713136046
# Iteration:     18,   Func. Count:    170,   Neg. LLF: 477.110450888473
# Iteration:     19,   Func. Count:    182,   Neg. LLF: 475.10663626646726
# Iteration:     20,   Func. Count:    194,   Neg. LLF: 469.6545462269025
# Iteration:     21,   Func. Count:    204,   Neg. LLF: 469.65454876100756
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 469.65454238043
#             Iterations: 22
#             Function evaluations: 205
#             Gradient evaluations: 21
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 727.4587948181685
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 644.6838015746587
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 649.742324944531
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 639.402940987049
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 637.3602579548051
# Iteration:      6,   Func. Count:     35,   Neg. LLF: 637.2969298047346
# Iteration:      7,   Func. Count:     40,   Neg. LLF: 637.2423705897653
# Iteration:      8,   Func. Count:     45,   Neg. LLF: 637.0953920011996
# Iteration:      9,   Func. Count:     50,   Neg. LLF: 637.0820332988199
# Iteration:     10,   Func. Count:     55,   Neg. LLF: 637.0812749416368
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 637.0812696925323
# Iteration:     12,   Func. Count:     64,   Neg. LLF: 637.0812697299096
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 637.0812696925323
#             Iterations: 12
#             Function evaluations: 64
#             Gradient evaluations: 12
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# ...
# Iteration:      7,   Func. Count:     39,   Neg. LLF: 659.4886181081038
# Iteration:      8,   Func. Count:     44,   Neg. LLF: 659.4865577283599
# Iteration:      9,   Func. Count:     49,   Neg. LLF: 659.482452853599
# Iteration:     10,   Func. Count:     54,   Neg. LLF: 659.4799021777934
# Iteration:     11,   Func. Count:     59,   Neg. LLF: 659.4779701725719
# Iteration:     12,   Func. Count:     64,   Neg. LLF: 659.4776831912432
# Iteration:     13,   Func. Count:     69,   Neg. LLF: 659.4776633463388
# Iteration:     14,   Func. Count:     73,   Neg. LLF: 659.4776633906242
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 659.4776633463388
#             Iterations: 14
#             Function evaluations: 73
#             Gradient evaluations: 14
# Iteration:      1,   Func. Count:     10,   Neg. LLF: 85013535.2532893
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 505.09484356706065
# Iteration:      3,   Func. Count:     31,   Neg. LLF: 495.7065857413947
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 492.47702790497476
# Iteration:      5,   Func. Count:     51,   Neg. LLF: 491.11840584178236
# Iteration:      6,   Func. Count:     60,   Neg. LLF: 491.13455436236535
# Iteration:      7,   Func. Count:     70,   Neg. LLF: 491.1029537661875
# Iteration:      8,   Func. Count:     79,   Neg. LLF: 491.09487290056165
# Iteration:      9,   Func. Count:     88,   Neg. LLF: 491.09287864040516
# Iteration:     10,   Func. Count:     97,   Neg. LLF: 491.09148649172704
# Iteration:     11,   Func. Count:    106,   Neg. LLF: 491.0898514347698
# Iteration:     12,   Func. Count:    115,   Neg. LLF: 491.0872171314527
# Iteration:     13,   Func. Count:    124,   Neg. LLF: 491.05933478465397
# Iteration:     14,   Func. Count:    133,   Neg. LLF: 491.39632477243737
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 491.05933408992496
#             Iterations: 14
#             Function evaluations: 136
#             Gradient evaluations: 14
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 4514.611458340401
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 690.3092452605459
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 669.6903303216691
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 679.4396414775986
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 665.5444680729531
# Iteration:      6,   Func. Count:     35,   Neg. LLF: 665.3644076383507
# Iteration:      7,   Func. Count:     40,   Neg. LLF: 665.2710975512477
# Iteration:      8,   Func. Count:     45,   Neg. LLF:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 496.84205483544014
#             Iterations: 23
#             Function evaluations: 216
#             Gradient evaluations: 22
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 4579.488103510967
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 705.8028260615067
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 690.0161918749045
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 717.9665215694756
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 678.8041994988271
# Iteration:      6,   Func. Count:     35,   Neg. LLF: 676.7396867833356
# Iteration:      7,   Func. Count:     40,   Neg. LLF: 676.6187910997228
# Iteration:      8,   Func. Count:     45,   Neg. LLF: 676.5368938584181
# Iteration:      9,   Func. Count:     50,   Neg. LLF: 676.4104016184374
# Iteration:     10,   Func. Count:     55,   Neg. LLF: 676.4086343831096
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 676.4003201408007
# Iteration:     12,   Func. Count:     65,   Neg. LLF: 676.3928460721806
# Iteration:     13,   Func. Count:     70,   Neg. LLF: 676.39274226867
# Iteration:     14,   Func. Count:     75,   Neg. LLF: 676.3927389829828
# Iteration:     15,   Func. Count:     79,   Neg. LLF: 676.3927390295239
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 676.3927389829828
#             Iterations: 15
#             Function evaluations: 79
#             Gradient evaluations: 15
# Iteration:      1,   Func. Count:     10,   Neg. LLF: 85898781.74390525
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 513.7314183729288
# Iteration:      3,   Func. Count:     31,   Neg. LLF: 504.3069486731098
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 501.26197618962794
# Iteration:      5,   Func. Count:     51,   Neg. LLF: 499.6224031573605
# Iteration:      6,   Func. Count:     60,   Neg. LLF: 499.6445633573767
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      7,   Func. Count:     70,   Neg. LLF: 499.6047920671581
# Iteration:      8,   Func. Count:     79,   Neg. LLF: 499.5954129137736
# Iteration:      9,   Func. Count:     88,   Neg. LLF: 499.5937950265077
# Iteration:     10,   Func. Count:     97,   Neg. LLF: 499.5912477166122
# Iteration:     11,   Func. Count:    106,   Neg. LLF: 499.58971858189346
# Iteration:     12,   Func. Count:    115,   Neg. LLF: 499.58753066616674
# Iteration:     13,   Func. Count:    124,   Neg. LLF: 499.5607163092526
# Iteration:     14,   Func. Count:    133,   Neg. LLF: 499.5660181187006
# Iteration:     15,   Func. Count:    143,   Neg. LLF: 499.55918445743276
# Iteration:     16,   Func. Count:    152,   Neg. LLF: 3526.3615662394864
# Iteration:     17,   Func. Count:    166,   Neg. LLF: 499.55896341085224
# Iteration:     18,   Func. Count:    175,   Neg. LLF: 499.55798070894025
# Iteration:     19,   Func. Count:    184,   Neg. LLF: 499.558988986384
# Iteration:     20,   Func. Count:    194,   Neg. LLF: 499.5579292498488
# Iteration:     21,   Func. Count:    202,   Neg. LLF: 499.55792925168794
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 499.5579292498488
#             Iterations: 22
#             Function evaluations: 202
#             Gradient evaluations: 21
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
print(Errors_A[3].mean())
print(Errors_GA[3].mean())
# Out:
# 2.9961293465306307
# 2.9811431508306514

# %%
print(Errors_A[3].mean())
print(Errors_B[3].mean())
print(Errors_C[3].mean())
# Out:
# 2.230273444349574
# 3.687067764224245
# 2.129617243935098

# %%
# Out:
# 3.7359688215897933

# %%
Errors_001=[]
for i in range(0,13): 
    Y_train=Y_t.iloc[:153+i]
    Y_test=Y_t.iloc[153+i:154+i]

    garch = arch_model(Y_train, vol="Garch", p=6, o=2, q=6, dist="skewt")
    garch_fitted = garch.fit(update_freq=1)
    garch_forecast = garch_fitted.forecast(horizon=1)
    garch_pred_mean = garch_forecast.mean['h.1'].iloc[-1]
    preds = pd.DataFrame([garch_pred_mean])

    mse = mean_squared_error(Y_test, preds)
    rmse = sqrt(mean_squared_error(Y_test, preds))
    mae = mean_absolute_error(Y_test, preds)
    mape=MAPE(Y_test, preds)
    Error_i = ([mse, rmse, mae, mape])
    Errors_001.append(Error_i)
    Errors_B=pd.DataFrame(Errors_001)
# Out:
# Iteration:      1,   Func. Count:     19,   Neg. LLF: 887.7692268803237
# Iteration:      2,   Func. Count:     41,   Neg. LLF: 14415.584282543045
# Iteration:      3,   Func. Count:     60,   Neg. LLF: 14486.973438657868
# Iteration:      4,   Func. Count:     79,   Neg. LLF: 5098.265831535791
# Iteration:      5,   Func. Count:     98,   Neg. LLF: 6023.290358003509
# Iteration:      6,   Func. Count:    117,   Neg. LLF: 3929.4552891053795
# Iteration:      7,   Func. Count:    136,   Neg. LLF: 6272.077829241549
# Iteration:      8,   Func. Count:    155,   Neg. LLF: 6266.07299010432
# Iteration:      9,   Func. Count:    174,   Neg. LLF: 944.3620864919816
# Iteration:     10,   Func. Count:    193,   Neg. LLF: 357.8469477022083
# Iteration:     11,   Func. Count:    212,   Neg. LLF: 1607.3887998682414
# Iteration:     12,   Func. Count:    231,   Neg. LLF: 278.5050561200402
# Iteration:     13,   Func. Count:    250,   Neg. LLF: 367.01080003604034
# Iteration:     14,   Func. Count:    269,   Neg. LLF: 367.90722950055397
# Iteration:     15,   Func. Count:    288,   Neg. LLF: 284.94227328275315
# Iteration:     16,   Func. Count:    307,   Neg. LLF: 166.1859880477739
# Iteration:     17,   Func. Count:    326,   Neg. LLF: 182.571374897417
# Iteration:     18,   Func. Count:    345,   Neg. LLF: 243.92843604347883
# Iteration:     19,   Func. Count:    364,   Neg. LLF: 141.01380076849927
# Iteration:     20,   Func. Count:    382,   Neg. LLF: 147.78478010577052
# Iteration:     21,   Func. Count:    401,   Neg. LLF: 201.97235836736536
# Iteration:     22,   Func. Count:    420,   Neg. LLF: 139.6978049789862
# Iteration:     23,   Func. Count:    438,   Neg. LLF: 139.49230340569437
# Iteration:     24,   Func. Count:    456,   Neg. LLF: 138.40547263183137
# Iteration:     25,   Func. Count:    474,   Neg. LLF: 640.0604766099368
# Iteration:     26,   Func. Count:    493,   Neg. LLF: 675.2478457340706
# Iteration:     27,   Func. Count:    512,   Neg. LLF: 700.1324771508375
# Iteration:     28,   Func. Count:    531,   Neg. LLF: 717.7729769550972
# Iteration:     29,   Func. Count:    550,   Neg. LLF: 721.0962760536669
# Iteration:     30,   Func. Count:    569,   Neg. LLF: 138.79672293403593
# Iteration:     31,   Func. Count:    588,   Neg. LLF: 666.1186977429596
# Iteration:     32,   Func. Count:    607,   Neg. LLF: 135.4516528493743
# Iteration:     33,   Func. Count:    625,   Neg. LLF: 135.34369142796712
# Iteration:     34,   Func. Count:    643,   Neg. LLF: 135.30156744964285
# Iteration:     35,   Func. Count:    661,   Neg. LLF: 135.2769252721012
# Iteration:     36,   Func. Count:    679,   Neg. LLF: 135.26195535806096
# Iteration:     37,   Func. Count:    697,   Neg. LLF: 135.25860556414636
# Iteration:     38,   Func. Count:    715,   Neg. LLF: 135.25597218810395
# Iteration:     39,   Func. Count:    733,   Neg. LLF: 135.2542720492765
# Iteration:     40,   Func. Count:    751,   Neg. LLF: 135.2540132829035
# Iteration:     41,   Func. Count:    769,   Neg. LLF: 135.25399640748753
# Iteration:     42,   Func. Count:    786,   Neg. LLF: 135.25399640743188
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 135.25399640748753
#             Iterations: 42
#             Function evaluations: 786
#             Gradient evaluations: 42
# Iteration:      1,   Func. Count:     19,   Neg. LLF: 894.3271653044217
# Iteration:      2,   Func. Count:     41,   Neg. LLF: 9032.431564382234
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      3,   Func. Count:     60,   Neg. LLF: 16336.140010744544
# Iteration:      4,   Func. Count:     79,   Neg. LLF: 6460.3226419735265
# Iteration:      5,   Func. Count:     98,   Neg. LLF: 3285.147073624068
# Iteration:      6,   Func. Count:    117,   Neg. LLF: 7312.6803249130535
# Iteration:      7,   Func. Count:    136,   Neg. LLF: 8816.390047662975
# Iteration:      8,   Func. Count:    155,   Neg. LLF: 4177.292568287295
# Iteration:      9,   Func. Count:    174,   Neg. LLF: 2373.0951708742705
# Iteration:     10,   Func. Count:    193,   Neg. LLF: 287.83685025821194
# Iteration:     11,   Func. Count:    212,   Neg. LLF: 381.51144048530676
# Iteration:     12,   Func. Count:    231,   Neg. LLF: 318.87208365443246
# Iteration:     13,   Func. Count:    250,   Neg. LLF: 282.2201647370864
# Iteration:     14,   Func. Count:    269,   Neg. LLF: 222.06045368783754
# Iteration:     15,   Func. Count:    288,   Neg. LLF: 261.1978552950719
# Iteration:     16,   Func. Count:    307,   Neg. LLF: 153.78776629220437
# Iteration:     17,   Func. Count:    325,   Neg. LLF: 191.90954172028506
# Iteration:     18,   Func. Count:    344,   Neg. LLF: 157.6283093322204
# Iteration:     19,   Func. Count:    363,   Neg. LLF: 263.3207007599765
# Iteration:     20,   Func. Count:    382,   Neg. LLF: 183.32425466454217
# Iteration:     21,   Func. Count:    401,   Neg. LLF: 162.70360120634228
# Iteration:     22,   Func. Count:    420,   Neg. LLF: 161.58552260726432
# Iteration:     23,   Func. Count:    439,   Neg. LLF: 145.13850219332434
# Iteration:     24,   Func. Count:    457,   Neg. LLF: 3253.891459024052
# Iteration:     25,   Func. Count:    476,   Neg. LLF: 159.53327401440788
# Iteration:     26,   Func. Count:    495,   Neg. LLF: 141.8278101093066
# Iteration:     27,   Func. Count:    513,   Neg. LLF: 141.1590776491641
# Iteration:     28,   Func. Count:    531,   Neg. LLF: 140.90883845550908
# Iteration:     29,   Func. Count:    549,   Neg. LLF: 139.91451261343394
# Iteration:     30,   Func. Count:    567,   Neg. LLF: 152.0487470700047
# Iteration:     31,   Func. Count:    586,   Neg. LLF: 659.7094390944962
# Iteration:     32,   Func. Count:    605,   Neg. LLF: 680.7453544838644
# Iteration:     33,   Func. Count:    624,   Neg. LLF: 678.7372335505999
# Iteration:     34,   Func. Count:    643,   Neg. LLF: 681.587468462892
# Iteration:     35,   Func. Count:    662,   Neg. LLF: 682.5082982404867
# Iteration:     36,   Func. Count:    681,   Neg. LLF: 138.4219665628729
# Iteration:     37,   Func. Count:    700,   Neg. LLF: 136.14552812947582
# Iteration:     38,   Func. Count:    718,   Neg. LLF: 680.9845734676952
# Iteration:     39,   Func. Count:    737,   Neg. LLF: 135.4586020939194
# Iteration:     40,   Func. Count:    755,   Neg. LLF: 134.9268416333962
# Iteration:     41,   Func. Count:    773,   Neg. LLF: 134.62462032714436
# Iteration:     42,   Func. Count:    791,   Neg. LLF: 134.5378012910041
# Iteration:     43,   Func. Count:    809,   Neg. LLF: 134.44747091686742
# Iteration:     44,   Func. Count:    827,   Neg. LLF: 134.42849078349298
# Iteration:     45,   Func. Count:    845,   Neg. LLF: 134.42252257311753
# Iteration:     46,   Func. Count:    863,   Neg. LLF: 134.41138194163696
# Iteration:     47,   Func. Count:    881,   Neg. LLF: 134.40402397808168
# Iteration:     48,   Func. Count:    899,   Neg. LLF: 134.4007312507033
# Iteration:     49,   Func. Count:    917,   Neg. LLF: 134.40001463162275
# Iteration:     50,   Func. Count:    935,   Neg. LLF: 134.399937255423
# Iteration:     51,   Func. Count:    953,   Neg. LLF: 134.39993302180972
# Iteration:     52,   Func. Count:    970,   Neg. LLF: 134.39993302180574
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 134.39993302180972
#             Iterations: 52
#             Function evaluations: 970
#             Gradient evaluations: 52
# Iteration:      1,   Func. Count:     19,   Neg. LLF: 900.6662692043603
# Iteration:      2,   Func. Count:     41,   Neg. LLF: 8995.71317664129
# Iteration:      3,   Func. Count:     60,   Neg. LLF: 19154.33687308042
# Iteration:      4,   Func. Count:     79,   Neg. LLF: 11806.949076281888
# Iteration:      5,   Func. Count:     98,   Neg. LLF: 3237.131422369246
# Iteration:      6,   Func. Count:    117,   Neg. LLF: 7078.987188311716
# Iteration:      7,   Func. Count:    136,   Neg. LLF: 4082.901915269343
# Iteration:      8,   Func. Count:    155,   Neg. LLF: 3627.552433455212
# Iteration:      9,   Func. Count:    174,   Neg. LLF: 1596.2004085794035
# Iteration:     10,   Func. Count:    193,   Neg. LLF: 344.52547979908456
# Iteration:     11,   Func. Count:    212,   Neg. LLF: 359.52627449802435
# Iteration:     12,   Func. Count:    231,   Neg. LLF: 332.454822524963
# Iteration:     13,   Func. Count:    250,   Neg. LLF: 321.0269327495741
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     14,   Func. Count:    269,   Neg. LLF: 359.4550329663968
# Iteration:     15,   Func. Count:    288,   Neg. LLF: 152.46948437656988
# Iteration:     16,   Func. Count:    306,   Neg. LLF: 181.79663213832606
# Iteration:     17,   Func. Count:    325,   Neg. LLF: 208.22810762508306
# Iteration:     18,   Func. Count:    346,   Neg. LLF: 141.93015148635104
# Iteration:     19,   Func. Count:    364,   Neg. LLF: 154.01205994678722
# Iteration:     20,   Func. Count:    383,   Neg. LLF:
# Iteration:     14,   Func. Count:    269,   Neg. LLF: 155.24377411649675
# Iteration:     15,   Func. Count:    287,   Neg. LLF: 265.71464583590875
# Iteration:     16,   Func. Count:    306,   Neg. LLF: 2375.343810931702
# Iteration:     17,   Func. Count:    325,   Neg. LLF: 168.41572153158694
# Iteration:     18,   Func. Count:    344,   Neg. LLF: 147.74117069213054
# Iteration:     19,   Func. Count:    362,   Neg. LLF: 266.4166889015209
# Iteration:     20,   Func. Count:    381,   Neg. LLF: 143.60219669419328
# Iteration:     21,   Func. Count:    399,   Neg. LLF: 143.63489170069312
# Iteration:     22,   Func. Count:    418,   Neg. LLF: 142.7646572340081
# Iteration:     23,   Func. Count:    436,   Neg. LLF: 141.78465760852592
# Iteration:     24,   Func. Count:    454,   Neg. LLF: 140.80924615306878
# Iteration:     25,   Func. Count:    472,   Neg. LLF: 139.3153426964904
# Iteration:     26,   Func. Count:    490,   Neg. LLF: 687.9278303063202
# Iteration:     27,   Func. Count:    509,   Neg. LLF: 138.95529903462352
# Iteration:     28,   Func. Count:    528,   Neg. LLF: 138.2053198999575
# Iteration:     29,   Func. Count:    546,   Neg. LLF: 138.01651196769805
# Iteration:     30,   Func. Count:    564,   Neg. LLF: 137.86182530182157
# Iteration:     31,   Func. Count:    582,   Neg. LLF: 137.708009679697
# Iteration:     32,   Func. Count:    600,   Neg. LLF: 137.66849472221378
# Iteration:     33,   Func. Count:    618,   Neg. LLF: 137.6632835785621
# Iteration:     34,   Func. Count:    636,   Neg. LLF: 137.66224587757074
# Iteration:     35,   Func. Count:    654,   Neg. LLF: 137.66210728441914
# Iteration:     36,   Func. Count:    672,   Neg. LLF: 137.6621032533503
# Iteration:     37,   Func. Count:    689,   Neg. LLF: 137.66210325336596
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 137.6621032533503
#             Iterations: 37
#             Function evaluations: 689
#             Gradient evaluations: 37
# Iteration:      1,   Func. Count:     19,   Neg. LLF: 927.03489109632
# Iteration:      2,   Func. Count:     41,   Neg. LLF: 9807.373044635604
# Iteration:      3,   Func. Count:     60,   Neg. LLF: 39679.70556347087
# Iteration:      4,   Func. Count:     79,   Neg. LLF: 11526.275888390013
# Iteration:      5,   Func. Count:     98,   Neg. LLF: 5481.52485460528
# Iteration:      6,   Func. Count:    117,   Neg. LLF: 7090.201796782469
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      7,   Func. Count:    136,   Neg. LLF: 4422.358807706347
# Iteration:      8,   Func. Count:    155,   Neg. LLF: 5345.784747214421
# Iteration:      9,   Func. Count:    174,   Neg. LLF: 2017.0929031997553
# Iteration:     10,   Func. Count:    193,   Neg. LLF: 428.3399856059593
# Iteration:     11,   Func. Count:    212,   Neg. LLF: 344.65120656200634
# Iteration:     12,   Func. Count:    231,   Neg. LLF: 280.7741658561954
# Iteration:     13,   Func. Count:    250,   Neg. LLF: 235.7848965032316
# Iteration:     14,   Func. Count:    269,   Neg. LLF: 159.95369602411182
# Iteration:     15,   Func. Count:    287,   Neg. LLF: 321.3770440065687
# Iteration:     16,   Func. Count:    306,   Neg. LLF: 973.1630905112694
# Iteration:     17,   Func. Count:    327,   Neg. LLF: 227.2444443393572
# Iteration:     18,   Func. Count:    347,   Neg. LLF: 150.49893785327646
# Iteration:     19,   Func. Count:    365,   Neg. LLF: 147.44805692006602
# Iteration:     20,   Func. Count:    383,   Neg. LLF: 205.66423414762528
# Iteration:     21,   Func. Count:    402,   Neg. LLF: 154.05939994714726
# Iteration:     22,   Func. Count:    421,   Neg. LLF: 146.34024807117166
# Iteration:     23,   Func. Count:    440,   Neg. LLF: 143.9902671998637
# Iteration:     24,   Func. Count:    458,   Neg. LLF: 143.44732984811202
# Iteration:     25,   Func. Count:    476,   Neg. LLF: 142.9350254101333
# Iteration:     26,   Func. Count:    494,   Neg. LLF: 140.16889578694875
# Iteration:     27,   Func. Count:    512,   Neg. LLF: 141.03181913563765
# Iteration:     28,   Func. Count:    531,   Neg. LLF: 141.29035580207895
# Iteration:     29,   Func. Count:    550,   Neg. LLF: 161.41669769461237
# Iteration:     30,   Func. Count:    569,   Neg. LLF: 150.72823590014772
# Iteration:     31,   Func. Count:    588,   Neg. LLF: 139.044607786907
# Iteration:     32,   Func. Count:    607,   Neg. LLF: 138.6131763098227
# Iteration:     33,   Func. Count:    625,   Neg. LLF: 138.55469974492942
# Iteration:     34,   Func. Count:    643,   Neg. LLF: 138.53169428750002
# Iteration:     35,   Func. Count:    661,   Neg. LLF: 138.52772338570975
# Iteration:     36,   Func. Count:    679,   Neg. LLF: 138.52682408531865
# Iteration:     37,   Func. Count:    697,   Neg. LLF: 138.52660428839954
# Iteration:     38,   Func. Count:    715,   Neg. LLF: 138.52656437125137
# Iteration:     39,   Func. Count:    733,   Neg. LLF: 138.52656268139606
# Iteration:     40,   Func. Count:    750,   Neg. LLF: 138.5265626814435
# Optimization terminated successfully    (Exit mode 0)
#             Current function value:
# Iteration:     35,   Func. Count:    660,   Neg. LLF: 140.10574197241135
# Iteration:     36,   Func. Count:    678,   Neg. LLF: 140.10557333868462
# Iteration:     37,   Func. Count:    696,   Neg. LLF: 140.10551623639628
# Iteration:     38,   Func. Count:    714,   Neg. LLF: 140.10550597872447
# Iteration:     39,   Func. Count:    732,   Neg. LLF: 140.1055054147805
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 140.1055054147805
#             Iterations: 39
#             Function evaluations: 732
#             Gradient evaluations: 39
# Iteration:      1,   Func. Count:     19,   Neg. LLF: 971.7541048383401
# Iteration:      2,   Func. Count:     41,   Neg. LLF: 15016.075270071773
# Iteration:      3,   Func. Count:     60,   Neg. LLF: 14304.855384655071
# Iteration:      4,   Func. Count:     79,   Neg. LLF: 25115.681059792765
# Iteration:      5,   Func. Count:     98,   Neg. LLF: 3185.483108034742
# Iteration:      6,   Func. Count:    117,   Neg. LLF: 9134.177344755326
# Iteration:      7,   Func. Count:    136,   Neg. LLF: 285.48944434235057
# Iteration:      8,   Func. Count:    155,   Neg. LLF: 596.9403105677444
# Iteration:      9,   Func. Count:    174,   Neg. LLF: 319.0175861805957
# Iteration:     10,   Func. Count:    193,   Neg. LLF: 1107.4176018936478
# Iteration:     11,   Func. Count:    212,   Neg. LLF: 335.6628818260267
# Iteration:     12,   Func. Count:    231,   Neg. LLF: 561.6568091998815
# Iteration:     13,   Func. Count:    250,   Neg. LLF: 229.62970877951548
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     14,   Func. Count:    269,   Neg. LLF: 316.7904010160529
# Iteration:     15,   Func. Count:    288,   Neg. LLF: 202.96703694264852
# Iteration:     16,   Func. Count:    307,   Neg. LLF: 169.22870506387267
# Iteration:     17,   Func. Count:    326,   Neg. LLF: 154.34163187282724
# Iteration:     18,   Func. Count:    345,   Neg. LLF: 175.30396105551046
# Iteration:     19,   Func. Count:    364,   Neg. LLF: 180.03327706220077
# Iteration:     20,   Func. Count:    383,   Neg. LLF: 149.57709829467208
# Iteration:     21,   Func. Count:    402,   Neg. LLF: 146.83046699829606
# Iteration:     22,   Func. Count:    420,   Neg. LLF: 145.7917471155204
# Iteration:     23,   Func. Count:    438,   Neg. LLF: 145.02513349669834
# Iteration:     24,   Func. Count:    456,   Neg. LLF: 669.2697399903958
# Iteration:     25,   Func. Count:    475,   Neg. LLF: 687.3745144150874
# Iteration:     26,   Func. Count:    494,   Neg. LLF: 705.3569276280683
# Iteration:     27,   Func. Count:    513,   Neg. LLF: 698.8397412123804
# Iteration:     28,   Func. Count:    532,   Neg. LLF: 698.1424979999682
# Iteration:     29,   Func. Count:    551,   Neg. LLF: 150.8505966669167
# Iteration:     30,   Func. Count:    570,   Neg. LLF: 143.0312487616658
# Iteration:     31,   Func. Count:    589,   Neg. LLF: 142.23409064596953
# Iteration:     32,   Func. Count:    607,   Neg. LLF: 142.20677476947395
# Iteration:     33,   Func. Count:    626,   Neg. LLF: 141.86735820830202
# Iteration:     34,   Func. Count:    644,   Neg. LLF: 141.5010964455319
# Iteration:     35,   Func. Count:    662,   Neg. LLF: 140.9819007711666
# Iteration:     36,   Func. Count:    680,   Neg. LLF: 140.9002819811346
# Iteration:     37,   Func. Count:    698,   Neg. LLF: 140.8661377649098
# Iteration:     38,   Func. Count:    716,   Neg. LLF: 140.84372728116938
# Iteration:     39,   Func. Count:    734,   Neg. LLF: 140.8422660426196
# Iteration:     40,   Func. Count:    752,   Neg. LLF: 140.84219282663872
# Iteration:     41,   Func. Count:    770,   Neg. LLF: 140.8421764608711
# Iteration:     42,   Func. Count:    788,   Neg. LLF: 140.84217309647715
# Iteration:     43,   Func. Count:    805,   Neg. LLF: 140.8421730964858
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 140.84217309647715
#             Iterations: 43
#             Function evaluations: 805
#             Gradient evaluations: 43
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
stock = web.get_data_yahoo("T",
start = "2021-01-01",
end = "2021-11-17")
y=stock['Adj Close']

Y_t=y.T
Y_t=Y_t.iloc[1:167]
Y_train=Y_t

model = pm.auto_arima(Y_train, start_p=3, start_q=3,start_d=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=6, max_q=6, max_d=2, # maximum p and q
                      m=1,              # frequency of series
                      d=1,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      #start_P=0, 
                      #D=1, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())

#ARIMA model
Errors_000=[]
for i in range(0,13):
    Y_train=Y_t.iloc[:153+i]
    Y_test=Y_t.iloc[153+i:154+i]
    
    arima_model = ARIMA(Y_train, order=model.order)
    arima_model_fit = arima_model.fit()
    preds_arima, se, conf = arima_model_fit.forecast(len(Y_test),alpha=0.3)  
    preds = pd.Series(preds_arima, index=Y_test.index)
    
    mse = mean_squared_error(Y_test, preds)
    rmse = sqrt(mean_squared_error(Y_test, preds))
    mae = mean_absolute_error(Y_test, preds)
    mape=MAPE(Y_test, preds)
    Error_i = ([mse, rmse, mae, mape])
    Errors_000.append(Error_i)
    Errors_A=pd.DataFrame(Errors_000)



#Garch model   
Errors_001=[]
for i in range(0,13): 
    Y_train=Y_t.iloc[:153+i]
    Y_test=Y_t.iloc[153+i:154+i]

    garch = arch_model(Y_train, vol="Garch", p=6, o=2, q=6, dist="skewt")
    garch_fitted = garch.fit(update_freq=5)
    garch_forecast = garch_fitted.forecast(horizon=1)
    garch_pred_mean = garch_forecast.mean['h.1'].iloc[-1]
    preds = pd.DataFrame([garch_pred_mean])

    mse = mean_squared_error(Y_test, preds)
    rmse = sqrt(mean_squared_error(Y_test, preds))
    mae = mean_absolute_error(Y_test, preds)
    mape=MAPE(Y_test, preds)
    Error_i = ([mse, rmse, mae, mape])
    Errors_001.append(Error_i)
    Errors_B=pd.DataFrame(Errors_001)

    
#ARIMA-GARCH model  
Errors_002=[]
for i in range(0,13):
    Y_train=Y_t.iloc[:153+i]
    Y_test=Y_t.iloc[153+i:154+i]
    
    arima_model = ARIMA(Y_train, order=(model.order))
    arima_model_fit = arima_model.fit()
    arima_residuals = arima_model_fit.resid
    p, d, q = model.order
    garch = arch_model(Y_train, vol="Garch", p=6, o=0, q=6, dist="skewt")
    garch_fitted = garch.fit()

    predicted_mu = arima_model_fit.forecast(len(Y_test))[0]
    # Use GARCH to predict the residual
    garch_forecast = garch_fitted.forecast(horizon=1)
    garch_pred_mean = garch_forecast.mean['h.1'].iloc[-1]
    garch_pred_var = garch_forecast.variance['h.1'].iloc[-1]


    # Combine both models' output: yt = mu + et
    preds = predicted_mu + garch_pred_var
    
    mse = mean_squared_error(Y_test, preds)
    rmse = sqrt(mean_squared_error(Y_test, preds))
    mae = mean_absolute_error(Y_test, preds)
    mape=MAPE(Y_test, preds)
    Error_i = ([mse, rmse, mae, mape])
    Errors_002.append(Error_i)
    Errors_C=pd.DataFrame(Errors_002)
    
    
# print(Errors_A[3].mean())
# print(Errors_GA[3].mean())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=83.223, Time=0.41 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=86.606, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=85.187, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=83.308, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=84.613, Time=0.02 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=85.217, Time=0.28 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=80.872, Time=0.37 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=79.432, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=81.905, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=81.079, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=82.440, Time=0.10 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=84.643, Time=0.22 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=82.859, Time=0.11 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=77.441, Time=0.11 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=79.919, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=79.094, Time=0.04 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=78.822, Time=0.25 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=83.230, Time=0.17 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=80.443, Time=0.05 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=82.652, Time=0.15 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=80.875, Time=0.08 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=80.463, Time=0.35 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 3.216 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  166
# Model:               SARIMAX(2, 1, 2)   Log Likelihood                 -33.720
# Date:                Mon, 22 Nov 2021   AIC                             77.441
# Time:                        06:23:16   BIC                             92.970
# Sample:                             0   HQIC                            83.745
#                                 - 166
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0118      0.117      0.101      0.919      -0.217       0.240
# ar.L2         -0.8517      0.115     -7.380      0.000      -1.078      -0.625
# ma.L1          0.1314      0.135      0.974      0.330      -0.133       0.396
# ma.L2          0.7806      0.138      5.661      0.000       0.510       1.051
# sigma2         0.0879      0.007     12.045      0.000       0.074       0.102
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):               134.44
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.38   Skew:                            -0.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 7810.4923442268155
# Iteration:     10,   Func. Count:    205,   Neg. LLF: 5265.074941601458
# Iteration:     15,   Func. Count:    305,   Neg. LLF: 214.90549513926175
# Iteration:     20,   Func. Count:    405,   Neg. LLF: 117.88538907298243
# Iteration:     25,   Func. Count:    505,   Neg. LLF: 110.71413757275887
# Iteration:     30,   Func. Count:    601,   Neg. LLF: 110.25719002747957
# Iteration:     35,   Func. Count:    700,   Neg. LLF: 142.65933632780167
# Iteration:     40,   Func. Count:    797,   Neg. LLF: 108.71788653626324
# Iteration:     45,   Func. Count:    892,   Neg. LLF: 108.57178654045642
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 108.5714732704996
#             Iterations: 50
#             Function evaluations: 968
#             Gradient evaluations: 49
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 8092.878783501108
# Iteration:     10,   Func. Count:    205,   Neg. LLF: 2713.7318987598296
# Iteration:     15,   Func. Count:    305,   Neg. LLF: 209.69203552266194
# Iteration:     20,   Func. Count:    404,   Neg. LLF: 110.68942993498419
# Iteration:     25,   Func. Count:    500,   Neg. LLF: 109.31514023859256
# Iteration:     30,   Func. Count:    598,   Neg. LLF: 108.03355044014907
# Iteration:     35,   Func. Count:    693,   Neg. LLF: 107.8582791578562
# Iteration:     40,   Func. Count:    789,   Neg. LLF: 107.85412511931855
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 107.85412511931855
#             Iterations: 41
#             Function evaluations: 789
#             Gradient evaluations: 40
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 1394.3913795113203
# Iteration:     10,   Func. Count:    215,   Neg. LLF: 5170.085196188363
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     15,   Func. Count:    315,   Neg. LLF: 3118.1463964632712
# Iteration:     20,   Func. Count:    415,   Neg. LLF: 131.19847118085443
# Iteration:     25,   Func. Count:    515,   Neg. LLF: 110.01469559261245
# Iteration:     30,   Func. Count:    610,   Neg. LLF: 699.9889720958918
# Iteration:     35,   Func. Count:    710,   Neg. LLF: 194.82791259279657
# Iteration:     40,   Func. Count:    808,   Neg. LLF: 107.55291473375469
# Iteration:     45,   Func. Count:    906,   Neg. LLF: 107.12835389979668
# Iteration:     50,   Func. Count:  1e+03,   Neg. LLF: 107.1257700782867
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 107.12574644868724
#             Iterations: 54
#             Function evaluations: 1059
#             Gradient evaluations: 53
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 1070.746709054622
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     10,   Func. Count:    203,   Neg. LLF: 2867.969488621565
# Iteration:     15,   Func. Count:    303,   Neg. LLF: 4572.90222123955
# Iteration:     20,   Func. Count:    403,   Neg. LLF: 115.47650660720117
# Iteration:     25,   Func. Count:    502,   Neg. LLF: 109.43994382020526
# Iteration:     30,   Func. Count:    599,   Neg. LLF: 111.47720563628414
# Iteration:     35,   Func. Count:    699,   Neg. LLF: 108.20888550012445
# Iteration:     40,   Func. Count:    798,   Neg. LLF: 106.433780732446
# Iteration:     45,   Func. Count:    893,   Neg. LLF: 106.42866943514355
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 106.42866862519011
#             Iterations: 47
#             Function evaluations: 912
#             Gradient evaluations: 46
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 1821.6424600873966
# Iteration:     10,   Func. Count:    206,   Neg. LLF: 4424.268001577913
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     15,   Func. Count:    306,   Neg. LLF: 472.33287372776124
# Iteration:     20,   Func. Count:    406,   Neg. LLF: 145.96848018065378
# Iteration:     25,   Func. Count:    505,   Neg. LLF: 125.60956957632027
# Iteration:     30,   Func. Count:    602,   Neg. LLF: 108.7514951014675
# Iteration:     35,   Func. Count:    701,   Neg. LLF: 107.58115097492751
# Iteration:     40,   Func. Count:    797,   Neg. LLF: 106.91255141127361
# Iteration:     45,   Func. Count:    894,   Neg. LLF: 106.86984311017542
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 106.86974405623863
#             Iterations: 50
#             Function evaluations: 969
#             Gradient evaluations: 49
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 8120.564659657484
# Iteration:     10,   Func. Count:    205,   Neg. LLF: 2863.4118024497575
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     15,   Func. Count:    305,   Neg. LLF: 163.77519706943593
# Iteration:     20,   Func. Count:    404,   Neg. LLF: 120.47690808319386
# Iteration:     25,   Func. Count:    504,   Neg. LLF: 755.480333117536
# Iteration:     30,   Func. Count:    603,   Neg. LLF: 108.87152773795285
# Iteration:     35,   Func. Count:    699,   Neg. LLF: 108.66320068147168
# Iteration:     40,   Func. Count:    794,   Neg. LLF: 108.55889569304728
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 108.55887260173355
#             Iterations: 45
#             Function evaluations: 869
#             Gradient evaluations: 44
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 2129.729729327999
# Iteration:     10,   Func. Count:    203,   Neg. LLF: 3024.160088735325
# Iteration:     15,   Func. Count:    303,   Neg. LLF: 143.60986205848198
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     20,   Func. Count:    403,   Neg. LLF: 113.96962997367359
# Iteration:     25,   Func. Count:    502,   Neg. LLF: 112.72579276705247
# Iteration:     30,   Func. Count:    601,   Neg. LLF: 111.9133873600787
# Iteration:     35,   Func. Count:    700,   Neg. LLF: 109.87412330053229
# Iteration:     40,   Func. Count:    798,   Neg. LLF: 109.83574881068435
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 109.83574673462422
#             Iterations: 43
#             Function evaluations: 835
#             Gradient evaluations: 42
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 8390.65202229875
# Iteration:     10,   Func. Count:    205,   Neg. LLF: 5590.097027117814
# Iteration:     15,   Func. Count:    305,   Neg. LLF: 167.7980060199701
# Iteration:     20,   Func. Count:    404,   Neg. LLF: 114.81021296687564
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     25,   Func. Count:    503,   Neg. LLF: 112.97714902381452
# Iteration:     30,   Func. Count:    601,   Neg. LLF: 119.24210863243157
# Iteration:     35,   Func. Count:    699,   Neg. LLF: 111.44822513809187
# Iteration:     40,   Func. Count:    795,   Neg. LLF: 111.31130078862421
# Iteration:     45,   Func. Count:    891,   Neg. LLF: 111.27864644282646
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 111.27864644282646
#             Iterations: 47
#             Function evaluations: 909
#             Gradient evaluations: 46
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 1776.3813589758242
# Iteration:     10,   Func. Count:    205,   Neg. LLF: 2757.1008917246786
# Iteration:     15,   Func. Count:    305,   Neg. LLF: 169.51721116130102
# Iteration:     20,   Func. Count:    404,   Neg. LLF: 116.43086941023938
# Iteration:     25,   Func. Count:    503,   Neg. LLF: 114.72273626031742
# Iteration:     30,   Func. Count:    601,   Neg. LLF: 115.9519749448659
# Iteration:     35,   Func. Count:    700,   Neg. LLF: 115.94532769973671
# Iteration:     40,   Func. Count:    796,   Neg. LLF: 112.89626669882155
# Iteration:     45,   Func. Count:    891,   Neg. LLF: 112.85058027814352
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 112.85046064084057
#             Iterations: 49
#             Function evaluations: 948
#             Gradient evaluations: 48
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 1443.5547944299092
# Iteration:     10,   Func. Count:    206,   Neg. LLF: 2945.4957028426124
# Iteration:     15,   Func. Count:    306,   Neg. LLF: 247.4582526691369
# Iteration:     20,   Func. Count:    406,   Neg. LLF: 119.96636160877385
# Iteration:     25,   Func. Count:    504,   Neg. LLF: 125.09959556522884
# Iteration:     30,   Func. Count:    604,   Neg. LLF: 116.18039965833343
# Iteration:     35,   Func. Count:    702,   Neg. LLF: 114.4283362091042
# Iteration:     40,   Func. Count:    799,   Neg. LLF: 114.33448675773178
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 114.33408457956631
#             Iterations: 45
#             Function evaluations: 874
#             Gradient evaluations: 44
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 7667.259092560848
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     10,   Func. Count:    205,   Neg. LLF: 5086.674856639473
# Iteration:     15,   Func. Count:    305,   Neg. LLF: 168.39634065461968
# Iteration:     20,   Func. Count:    405,   Neg. LLF: 119.0950416767824
# Iteration:     25,   Func. Count:    502,   Neg. LLF: 119.12055796755425
# Iteration:     30,   Func. Count:    601,   Neg. LLF: 117.01844518401445
# Iteration:     35,   Func. Count:    696,   Neg. LLF: 116.8740451443575
# Iteration:     40,   Func. Count:    794,   Neg. LLF: 116.75840586024296
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 116.75840465571709
#             Iterations: 43
#             Function evaluations: 831
#             Gradient evaluations: 42
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 1543.4312640078529
# Iteration:     10,   Func. Count:    205,   Neg. LLF: 2967.462535819863
# Iteration:     15,   Func. Count:    305,   Neg. LLF: 177.01277173313304
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     20,   Func. Count:    405,   Neg. LLF: 122.25367932769724
# Iteration:     25,   Func. Count:    503,   Neg. LLF: 120.16804560558066
# Iteration:     30,   Func. Count:    603,   Neg. LLF: 825.8937793128462
# Iteration:     35,   Func. Count:    702,   Neg. LLF: 118.74284431467485
# Iteration:     40,   Func. Count:    797,   Neg. LLF: 118.63441456059581
# Iteration:     45,   Func. Count:    893,   Neg. LLF: 118.60790136357875
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 118.60790136357875
#             Iterations: 47
#             Function evaluations: 911
#             Gradient evaluations: 46
# Iteration:      5,   Func. Count:    104,   Neg. LLF: 10827.123745362358
# Iteration:     10,   Func. Count:    204,   Neg. LLF: 6085.245558908904
# Iteration:     15,   Func. Count:    304,   Neg. LLF: 128.62329480328606
# Iteration:     20,   Func. Count:    404,   Neg. LLF: 122.4876981369577
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     25,   Func. Count:    501,   Neg. LLF: 121.9174539742358
# Iteration:     30,   Func. Count:    600,   Neg. LLF: 790.6920322383082
# Iteration:     35,   Func. Count:    698,   Neg. LLF: 120.79024076989828
# ...
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# Iteration:      1,   Func. Count:     18,   Neg. LLF: 965.8404311497591
# Iteration:      2,   Func. Count:     39,   Neg. LLF: 4969.336067780097
# Iteration:      3,   Func. Count:     57,   Neg. LLF: 354.59513723472367
# Iteration:      4,   Func. Count:     75,   Neg. LLF: 264.6434345088753
# Iteration:      5,   Func. Count:     93,   Neg. LLF: 5189.535066770448
# Iteration:      6,   Func. Count:    111,   Neg. LLF: 5115.114500840045
# Iteration:      7,   Func. Count:    129,   Neg. LLF: 5117.903057358206
# Iteration:      8,   Func. Count:    147,   Neg. LLF: 686.1722807582961
# Iteration:      9,   Func. Count:    167,   Neg. LLF: 5589.267078904216
# Iteration:     10,   Func. Count:    185,   Neg. LLF: 5588.727750476743
# Iteration:     11,   Func. Count:    203,   Neg. LLF: 670.7085705656349
# Iteration:     12,   Func. Count:    223,   Neg. LLF: 8748.148236257759
# Iteration:     13,   Func. Count:    241,   Neg. LLF: 5996.74238862522
# Iteration:     14,   Func. Count:    259,   Neg. LLF: 6845.878535299412
# Iteration:     15,   Func. Count:    277,   Neg. LLF: 2492.276405329736
# Iteration:     16,   Func. Count:    295,   Neg. LLF: 2258.7898852412736
# Iteration:     17,   Func. Count:    313,   Neg. LLF: 257.90805681987325
# Iteration:     18,   Func. Count:    331,   Neg. LLF: 3282.5294488848085
# Iteration:     19,   Func. Count:    349,   Neg. LLF: 161.61777773886155
# Iteration:     20,   Func. Count:    367,   Neg. LLF: 236.4700110263777
# Iteration:     21,   Func. Count:    385,   Neg. LLF: 121.39402415728082
# Iteration:     22,   Func. Count:    402,   Neg. LLF: 127.750478783597
# Iteration:     23,   Func. Count:    420,   Neg. LLF: 161.43096828094988
# Iteration:     24,   Func. Count:    439,   Neg. LLF: 121.4206641491587
# Iteration:     25,   Func. Count:    457,   Neg. LLF: 121.264616699083
# Iteration:     26,   Func. Count:    474,   Neg. LLF: 121.26061239458087
# Iteration:     27,   Func. Count:    491,   Neg. LLF: 121.25368219878942
# Iteration:     28,   Func. Count:    508,   Neg. LLF: 121.23918690068679
# Iteration:     29,   Func. Count:    525,   Neg. LLF: 121.22353353520313
# Iteration:     30,   Func. Count:    542,   Neg. LLF: 121.21851262664117
# Iteration:     31,   Func. Count:    559,   Neg. LLF: 121.21808081173964
# Iteration:     32,   Func. Count:    576,   Neg. LLF: 121.21804977231098
# Iteration:     33,   Func. Count:    593,   Neg. LLF: 121.21804709323696
# Iteration:     34,   Func. Count:    609,   Neg. LLF: 121.2180470933601
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 121.21804709323696
#             Iterations: 36
#             Function evaluations: 609
#             Gradient evaluations: 34
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# Iteration:      1,   Func. Count:     18,   Neg. LLF: 971.0011332381599
# Iteration:      2,   Func. Count:     39,   Neg. LLF: 4940.985583907483
# Iteration:      3,   Func. Count:     57,   Neg. LLF: 464.3875364215954
# Iteration:      4,   Func. Count:     75,   Neg. LLF: 393.47116033780185
# Iteration:      5,   Func. Count:     93,   Neg. LLF: 295.28953597470775
# Iteration:      6,   Func. Count:    111,   Neg. LLF: 4807.510337480317
# Iteration:      7,   Func. Count:    129,   Neg. LLF: 714.5142079239406
# Iteration:      8,   Func. Count:    149,   Neg. LLF: 10850.720996965632
# Iteration:      9,   Func. Count:    167,   Neg. LLF: 6042.4078442877735
# Iteration:     10,   Func. Count:    185,   Neg. LLF: 5910.846122036166
# Iteration:     11,   Func. Count:    203,   Neg. LLF: 4682.080487200044
# Iteration:     12,   Func. Count:    221,   Neg. LLF: 5110.049561835649
# Iteration:     13,   Func. Count:    239,   Neg. LLF: 455.43759660255085
# Iteration:     14,   Func. Count:    257,   Neg. LLF: 4806.578379448911
# Iteration:     15,   Func. Count:    275,   Neg. LLF: 467.1626828268686
# Iteration:     16,   Func. Count:    293,   Neg. LLF: 223.07952612741576
# Iteration:     17,   Func. Count:    311,   Neg. LLF: 419.15272986073535
# Iteration:     18,   Func. Count:    329,   Neg. LLF: 134.08842263722389
# Iteration:     19,   Func. Count:    347,   Neg. LLF: 210.76611320523836
# Iteration:     20,   Func. Count:    365,   Neg. LLF: 123.79980381090485
# Iteration:     21,   Func. Count:    382,   Neg. LLF: 129.1427855661976
# Iteration:     22,   Func. Count:    400,   Neg. LLF: 125.2869127020652
# Iteration:     23,   Func. Count:    418,   Neg. LLF: 131.73946943958646
# Iteration:     24,   Func. Count:    436,   Neg. LLF: 123.12217580255592
# Iteration:     25,   Func. Count:    454,   Neg. LLF: 129.46139344360043
# Iteration:     26,   Func. Count:    472,   Neg. LLF: 122.97786592152411
# Iteration:     27,   Func. Count:    489,   Neg. LLF: 122.97055192146779
# Iteration:     28,   Func. Count:    506,   Neg. LLF: 122.95980399474854
# Iteration:     29,   Func. Count:    523,   Neg. LLF: 122.94613812815125
# Iteration:     30,   Func. Count:    540,   Neg. LLF: 122.94258448878645
# Iteration:     31,   Func. Count:    557,   Neg. LLF: 122.93937186355507
# Iteration:     32,   Func. Count:    574,   Neg. LLF: 122.93748845901816
# Iteration:     33,   Func. Count:    591,   Neg. LLF: 122.93366085025696
# Iteration:     34,   Func. Count:    608,   Neg. LLF: 122.9285652610366
# Iteration:     35,   Func. Count:    625,   Neg. LLF: 122.92615404767028
# Iteration:     36,   Func. Count:    642,   Neg. LLF: 122.92598627350543
# Iteration:     37,   Func. Count:    659,   Neg. LLF: 122.92598249151202
# Iteration:     38,   Func. Count:    675,   Neg. LLF: 122.92598249166059
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 122.92598249151202
#             Iterations: 39
#             Function evaluations: 675
#             Gradient evaluations: 38
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# Iteration:      1,   Func. Count:     18,   Neg. LLF: 976.5841085646972
# Iteration:      2,   Func. Count:     39,   Neg. LLF: 5182.019008482057
# Iteration:      3,   Func. Count:     57,   Neg. LLF: 418.373682046721
# Iteration:      4,   Func. Count:     75,   Neg. LLF: 362.73867823662704
# Iteration:      5,   Func. Count:     93,   Neg. LLF: 411.4677932428101
# Iteration:      6,   Func. Count:    111,   Neg. LLF: 209.92604572659695
# Iteration:      7,   Func. Count:    129,   Neg. LLF: 10342.536276509562
# Iteration:      8,   Func. Count:    150,   Neg. LLF: 788.9837261868599
# Iteration:      9,   Func. Count:    170,   Neg. LLF: 9928.3572120645
# Iteration:     10,   Func. Count:    188,   Neg. LLF: 4148.469718146439
# Iteration:     11,   Func. Count:    206,   Neg. LLF: 4284.368163982292
# Iteration:     12,   Func. Count:    224,   Neg. LLF: 7975.546628003085
# Iteration:     13,   Func. Count:    242,   Neg. LLF: 540.0911395483097
# Iteration:     14,   Func. Count:    260,   Neg. LLF: 5095.009806601162
# Iteration:     15,   Func. Count:    278,   Neg. LLF: 369.25513312361807
# Iteration:     16,   Func. Count:    296,   Neg. LLF: 373.8012584640104
# Iteration:     17,   Func. Count:    314,   Neg. LLF: 276.1376165603201
# Iteration:     18,   Func. Count:    332,   Neg. LLF: 133.38425946123502
# Iteration:     19,   Func. Count:    350,   Neg. LLF: 226.58279670061725
# Iteration:     20,   Func. Count:    368,   Neg. LLF: 138.63742643704953
# Iteration:     21,   Func. Count:    386,   Neg. LLF: 124.90826557699884
# Iteration:     22,   Func. Count:    403,   Neg. LLF: 124.64025235716902
# Iteration:     23,   Func. Count:    420,   Neg. LLF: 124.83752834819859
# Iteration:     24,   Func. Count:    438,   Neg. LLF: 124.74030338233734
# Iteration:     25,   Func. Count:    456,   Neg. LLF: 124.58475767743312
# Iteration:     26,   Func. Count:    473,   Neg. LLF: 124.5780385015882
# Iteration:     27,   Func. Count:    490,   Neg. LLF: 124.56546885998145
# Iteration:     28,   Func. Count:    507,   Neg. LLF: 124.56342820628683
# Iteration:     29,   Func. Count:    524,   Neg. LLF: 124.55531443728538
# Iteration:     30,   Func. Count:    541,   Neg. LLF: 124.5437370917601
# Iteration:     31,   Func. Count:    558,   Neg. LLF: 124.53580956931668
# Iteration:     32,   Func. Count:    575,   Neg. LLF: 124.53621850109644
# Iteration:     33,   Func. Count:    593,   Neg. LLF: 124.53401238006839
# Iteration:     34,   Func. Count:    610,   Neg. LLF: 124.53399549585336
# Iteration:     35,   Func. Count:    626,   Neg. LLF: 124.53399549585666
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 124.53399549585336
#             Iterations: 36
#             Function evaluations: 626
#             Gradient evaluations: 35
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
print(Errors_A[3].mean())
print(Errors_B[3].mean())
print(Errors_C[3].mean())
# Out:
# 0.5385308835477641
# 1.9241065922405822
# 1.857648901930933

# %%
Errors_1=[]
for i in range(0,13):
    Y_train=Y_t.iloc[:153+i]
    Y_test=Y_t.iloc[153+i:154+i]
    
    arima_model = ARIMA(Y_train, order=model.order)
    arima_model_fit = arima_model.fit()
    preds_arima, se, conf = arima_model_fit.forecast(len(Y_test),alpha=0.3)  
    predicted_arima = pd.Series(preds_arima, index=Y_test.index)

    garch_model = arch_model(Y_train, vol='garch', p=1, q=1)
    garch_model_fit = garch_model.fit()
    preds_garch = garch_model_fit.forecast(horizon=len(Y_test)) 
    predicted_garch = preds_garch.mean['h.1'].iloc[-1]



    # arima_model_fitted = pm.auto_arima(Y_train)
    arima_residuals = arima_model_fit.resid
    p, d, q = model.order
    garch = arch_model(arima_residuals, p=3, q=3)
    garch_fitted = garch.fit()

    predicted_mu = arima_model_fit.forecast(len(Y_test))[0]
    # Use GARCH to predict the residual
    garch_forecast = garch_fitted.forecast(horizon=1)
    garch_pred_mean = garch_forecast.mean['h.1'].iloc[-1]
    garch_pred_var = garch_forecast.variance['h.1'].iloc[-1]


    # Combine both models' output: yt = mu + et
    preds = predicted_mu + garch_pred_mean
    
    mse = mean_squared_error(Y_test, preds)
    rmse = sqrt(mean_squared_error(Y_test, preds))
    mae = mean_absolute_error(Y_test, preds)
    mape=MAPE(Y_test, preds)
    Error_i = ([mse, rmse, mae, mape])
    Errors_1.append(Error_i)
    Errors_GA=pd.DataFrame(Errors_1)
